# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragal/deep-learning/blob/master/deep-learning/S12/Assignment_B/yolo_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/anuragal/deep-learning deep_learning
! ls 'deep_learning/S12/Assignment_B'
# Out:
# Cloning into 'deep_learning'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 121694 (delta 89), reused 98 (delta 51), pack-reused 121553
# Receiving objects: 100% (121694/121694), 222.21 MiB | 29.36 MiB/s, done.
# Resolving deltas: 100% (1662/1662), done.
# Checking out files: 100% (120401/120401), done.
#  annotations.json     dog_images    via_project_27Jun2020_14h37m.json
# 'Class Excel.xlsx'    __init__.py
#  data_processing.py   kmc.py

# %%
! cd 'deep_learning' && git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/anuragal/deep-learning
#    753433572..81ce7814e  master     -> origin/master
# Updating 753433572..81ce7814e
# Fast-forward
#  S12/Assignment_B/data_processing.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# ## K-means Clustering
#
# K-Means Clustering is an unsupervised machine learning algorithm. In contrast to traditional supervised machine learning algorithms, K-Means attempts to classify data without having first been trained with labeled data.
#
# This colab file consist of
# 1. 50 images of dogs are annotated by creating bounding boxes
# 2. Created JSON File
# 3. Finding out the best total numbers of clusters

# %% [markdown]
# ## Load and Process Annotated Data

# %%
from deep_learning.S12.Assignment_B.data_processing import AnnotatedData

ad = AnnotatedData()
annotated_data = ad.load('deep_learning/S12/Assignment_B/annotations.json')
ad.process_images('deep_learning/S12/Assignment_B/dog_images')
processed_data = ad.process_data(annotated_data)

# %%
processed_data.iloc[0]
# Out:
# name                   dog1.jfif
# bbox_height                  197
# bbox_width                    98
# bbox_x                        67
# bbox_y                         6
# img_height                   215
# img_width                    234
# bbox_rel_height         0.916279
# bbox_rel_width          0.418803
# bbox_rel_log_height   -0.0874343
# bbox_rel_log_width     -0.870354
# Name: 0, dtype: object

# %%
ad.plot_images('deep_learning/S12/Assignment_B/dog_images', processed_data, 5)

# %%
ad.plot_scatter()

# %%
ad.plot_scatter(log_values=True)

# %% [markdown]
# ## Apply K Means Clustering

# %%
from deep_learning.S12.Assignment_B.kmc import kmc_elbow, plot_clusters

# %% [markdown]
# ## Using Elbow method

# %%
kmc_elbow(processed_data)

# %% [markdown]
# Seeing above graph the optimum number of clusters are 6

# %% [markdown]
# ### With 2 Clusters

# %%
plot_clusters(2, processed_data)

# %% [markdown]
# ### With 3 Clusters

# %%
plot_clusters(3, processed_data)

# %% [markdown]
# ### With 4 Clusters

# %%
plot_clusters(4, processed_data)

# %% [markdown]
# ### With 6 Clusters

# %%
plot_clusters(6, processed_data)
