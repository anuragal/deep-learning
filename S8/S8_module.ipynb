# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragal/deep-learning/blob/master/S8/S8_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Model

# %%
# !pip install torchsummary
from torchsummary import summary

from models.ResNet18 import ResNet18

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = ResNet18().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# ...
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %% [markdown]
# ## Run the Model

# %%
from dataloader import ImageData
from models.ResNet18 import ResNet18
from datamodel import DataModel

# Loading CIFAR10 data and transforming it
img_data = ImageData()
img_data.load()

# training the dataset and then running test
dm = DataModel(num_of_epochs = 50, cal_misclassified = True)
dm.run_model(ResNet18())
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# Loss=1.1331168413162231 Batch_id=390 Accuracy=40.82: 100%|██████████| 391/391 [03:12<00:00,  2.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0164, Accuracy: 4812/10000 (48.12%)
#
# EPOCH: 2
# Loss=0.9389791488647461 Batch_id=390 Accuracy=61.60: 100%|██████████| 391/391 [03:06<00:00,  2.10it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0092, Accuracy: 6751/10000 (67.51%)
#
# EPOCH: 3
# Loss=0.7493717074394226 Batch_id=390 Accuracy=71.94: 100%|██████████| 391/391 [03:03<00:00,  2.13it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0077, Accuracy: 7251/10000 (72.51%)
#
# EPOCH: 4
# Loss=0.6306663751602173 Batch_id=390 Accuracy=78.03: 100%|██████████| 391/391 [03:17<00:00,  1.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0067, Accuracy: 7648/10000 (76.48%)
#
# EPOCH: 5
# ...

# %% [markdown]
# ## Plotting Validation Accuracy

# %%
dm.plot_accuracy_graph()

# %% [markdown]
# ## Plotting Loss Graph

# %%
dm.plot_loss_graph()

# %% [markdown]
# ## Plotting Misclassified Images

# %%
dm.plot_misclassified()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
